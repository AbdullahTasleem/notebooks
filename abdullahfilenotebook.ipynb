# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Abdullah Tasleem**
#
# Current Occupation: Technical seller - Desired Occupation: Data Scientist

# %% [markdown]
# _I am interested in Data Science because I think this is the field that will unclock many hidden insights to solve world problems_

# %% [markdown]
# ### The below should print 'Hello World'

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# > If they can do it, so can you.
# >
#  - Ath
#  - unkown
#
# <hr>
#
# Made with <3 [My Github](https://github.com/AbdullahTasleem)
